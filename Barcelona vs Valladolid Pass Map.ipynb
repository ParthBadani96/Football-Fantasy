# %%
import pandas as pd
from mplsoccer.pitch import Pitch

# %%
#read in CSV
df = pd.read_csv("C:/Users/Parth Badani/Downloads/valladolidA.csv")

# %%
df
# Out:
#               id  eventId  minute  second      teamId     x     y  period  \
# 0     2248226915        2       0     0.0   Barcelona   0.0   0.0       1
# 1     2248226919        2       0     0.0  Valladolid   0.0   0.0       1
# 2     2248226929        3       0     1.0   Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0   Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0   Barcelona  36.6  56.6       1
# ...          ...      ...     ...     ...         ...   ...   ...     ...
# 1673  2248257153     1030      94     0.0   Barcelona   0.0   0.0       2
# 1674  2248257159      779       0     0.0  Valladolid   0.0   0.0      14
# 1675  2248257147     1031       0     0.0   Barcelona   0.0   0.0      14
# 1676  2248274127        1       0     0.0  Valladolid   0.0   0.0      16
# 1677  2248257151        1       0     0.0   Barcelona   0.0   0.0      16
#
#               type     outcome  playerId  endX  endY
# 0            Start  Successful       NaN   NaN   NaN
# 1            Start  Successful       NaN   NaN   NaN
# 2             Pass  Successful       9.0  43.9  46.9
# 3             Pass  Successful       8.0  36.4  56.0
# 4             Pass  Successful      21.0  28.5  73.8
# ...            ...         ...       ...   ...   ...
# 1673           End  Successful       NaN   NaN   NaN
# 1674           End  Successful       NaN   NaN   NaN
# 1675           End  Successful       NaN   NaN   NaN
# 1676  FormationSet  Successful       NaN   NaN   NaN
# 1677  FormationSet  Successful       NaN   NaN   NaN
#
# [1678 rows x 13 columns]

# %%
df = df[df['teamId']=='Barcelona']

# %%
df
# Out:
#               id  eventId  minute  second     teamId     x     y  period  \
# 0     2248226915        2       0     0.0  Barcelona   0.0   0.0       1
# 2     2248226929        3       0     1.0  Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0  Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0  Barcelona  36.6  56.6       1
# 5     2248226973        6       0     5.0  Barcelona  28.3  74.1       1
# ...          ...      ...     ...     ...        ...   ...   ...     ...
# 1668  2248257083     1028      93    55.0  Barcelona  77.1  49.0       2
# 1671  2248257093     1029      93    57.0  Barcelona  86.9  49.6       2
# 1673  2248257153     1030      94     0.0  Barcelona   0.0   0.0       2
# 1675  2248257147     1031       0     0.0  Barcelona   0.0   0.0      14
# 1677  2248257151        1       0     0.0  Barcelona   0.0   0.0      16
#
#                type     outcome  playerId  endX  endY
# 0             Start  Successful       NaN   NaN   NaN
# 2              Pass  Successful       9.0  43.9  46.9
# 3              Pass  Successful       8.0  36.4  56.0
# 4              Pass  Successful      21.0  28.5  73.8
# 5              Pass  Successful      15.0  11.6  51.8
# ...             ...         ...       ...   ...   ...
# 1668      SavedShot  Successful      10.0   NaN   NaN
# 1671  CornerAwarded  Successful      10.0   NaN   NaN
# 1673            End  Successful       NaN   NaN   NaN
# 1675            End  Successful       NaN   NaN   NaN
# 1677   FormationSet  Successful       NaN   NaN   NaN
#
# [962 rows x 13 columns]

# %%
df['passer'] = df['playerId']
df['recipient'] = df['playerId'].shift(-1)
passes = df[df['type']=='Pass']
successful = df[df['outcome']=='Successful']
# Out:
# C:\Users\Parth Badani\AppData\Local\Temp\ipykernel_79840\4249512153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['passer'] = df['playerId']
# C:\Users\Parth Badani\AppData\Local\Temp\ipykernel_79840\4249512153.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['recipient'] = df['playerId'].shift(-1)

# %%
successful
# Out:
#               id  eventId  minute  second     teamId     x     y  period  \
# 0     2248226915        2       0     0.0  Barcelona   0.0   0.0       1
# 2     2248226929        3       0     1.0  Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0  Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0  Barcelona  36.6  56.6       1
# 5     2248226973        6       0     5.0  Barcelona  28.3  74.1       1
# ...          ...      ...     ...     ...        ...   ...   ...     ...
# 1668  2248257083     1028      93    55.0  Barcelona  77.1  49.0       2
# 1671  2248257093     1029      93    57.0  Barcelona  86.9  49.6       2
# 1673  2248257153     1030      94     0.0  Barcelona   0.0   0.0       2
# 1675  2248257147     1031       0     0.0  Barcelona   0.0   0.0      14
# 1677  2248257151        1       0     0.0  Barcelona   0.0   0.0      16
#
#                type     outcome  playerId  endX  endY  passer  recipient
# 0             Start  Successful       NaN   NaN   NaN     NaN        9.0
# 2              Pass  Successful       9.0  43.9  46.9     9.0        8.0
# 3              Pass  Successful       8.0  36.4  56.0     8.0       21.0
# 4              Pass  Successful      21.0  28.5  73.8    21.0       15.0
# 5              Pass  Successful      15.0  11.6  51.8    15.0        1.0
# ...             ...         ...       ...   ...   ...     ...        ...
# 1668      SavedShot  Successful      10.0   NaN   NaN    10.0       10.0
# 1671  CornerAwarded  Successful      10.0   NaN   NaN    10.0        NaN
# 1673            End  Successful       NaN   NaN   NaN     NaN        NaN
# 1675            End  Successful       NaN   NaN   NaN     NaN        NaN
# 1677   FormationSet  Successful       NaN   NaN   NaN     NaN        NaN
#
# [837 rows x 15 columns]

# %%
subs = df[df['type']=='SubstitutionOff']
subs = subs['minute']
firstSub = subs.min()

# %%
firstSub
# Out:
# 70

# %%
successful = successful[successful['minute']<firstSub]

# %%
successful
# Out:
#               id  eventId  minute  second     teamId     x     y  period  \
# 0     2248226915        2       0     0.0  Barcelona   0.0   0.0       1
# 2     2248226929        3       0     1.0  Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0  Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0  Barcelona  36.6  56.6       1
# 5     2248226973        6       0     5.0  Barcelona  28.3  74.1       1
# ...          ...      ...     ...     ...        ...   ...   ...     ...
# 1235  2248252905      786      69    37.0  Barcelona  90.7  14.3       2
# 1236  2248252913      787      69    38.0  Barcelona  88.4  15.3       2
# 1240  2248252925      789      69    46.0  Barcelona  90.2   5.8       2
# 1675  2248257147     1031       0     0.0  Barcelona   0.0   0.0      14
# 1677  2248257151        1       0     0.0  Barcelona   0.0   0.0      16
#
#               type     outcome  playerId  endX  endY  passer  recipient
# 0            Start  Successful       NaN   NaN   NaN     NaN        9.0
# 2             Pass  Successful       9.0  43.9  46.9     9.0        8.0
# 3             Pass  Successful       8.0  36.4  56.0     8.0       21.0
# 4             Pass  Successful      21.0  28.5  73.8    21.0       15.0
# 5             Pass  Successful      15.0  11.6  51.8    15.0        1.0
# ...            ...         ...       ...   ...   ...     ...        ...
# 1235          Pass  Successful       2.0  88.4  15.3     2.0        8.0
# 1236          Pass  Successful       8.0  80.1  33.0     8.0       16.0
# 1240   BlockedPass  Successful      16.0   NaN   NaN    16.0        4.0
# 1675           End  Successful       NaN   NaN   NaN     NaN        NaN
# 1677  FormationSet  Successful       NaN   NaN   NaN     NaN        NaN
#
# [639 rows x 15 columns]

# %%
pas = pd.to_numeric(successful['passer'], downcast = 'integer')
rec = pd.to_numeric(successful['recipient'], downcast = 'integer')

successful['passer'] = pas
successful['recipient'] = rec
# Out:
# C:\Users\Parth Badani\AppData\Local\Temp\ipykernel_79840\1495589847.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successful['passer'] = pas
# C:\Users\Parth Badani\AppData\Local\Temp\ipykernel_79840\1495589847.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successful['recipient'] = rec

# %%
successful
# Out:
#               id  eventId  minute  second     teamId     x     y  period  \
# 0     2248226915        2       0     0.0  Barcelona   0.0   0.0       1
# 2     2248226929        3       0     1.0  Barcelona  50.0  50.0       1
# 3     2248226941        4       0     2.0  Barcelona  43.8  46.9       1
# 4     2248226951        5       0     4.0  Barcelona  36.6  56.6       1
# 5     2248226973        6       0     5.0  Barcelona  28.3  74.1       1
# ...          ...      ...     ...     ...        ...   ...   ...     ...
# 1235  2248252905      786      69    37.0  Barcelona  90.7  14.3       2
# 1236  2248252913      787      69    38.0  Barcelona  88.4  15.3       2
# 1240  2248252925      789      69    46.0  Barcelona  90.2   5.8       2
# 1675  2248257147     1031       0     0.0  Barcelona   0.0   0.0      14
# 1677  2248257151        1       0     0.0  Barcelona   0.0   0.0      16
#
#               type     outcome  playerId  endX  endY  passer  recipient
# 0            Start  Successful       NaN   NaN   NaN     NaN        9.0
# 2             Pass  Successful       9.0  43.9  46.9     9.0        8.0
# 3             Pass  Successful       8.0  36.4  56.0     8.0       21.0
# 4             Pass  Successful      21.0  28.5  73.8    21.0       15.0
# 5             Pass  Successful      15.0  11.6  51.8    15.0        1.0
# ...            ...         ...       ...   ...   ...     ...        ...
# 1235          Pass  Successful       2.0  88.4  15.3     2.0        8.0
# 1236          Pass  Successful       8.0  80.1  33.0     8.0       16.0
# 1240   BlockedPass  Successful      16.0   NaN   NaN    16.0        4.0
# 1675           End  Successful       NaN   NaN   NaN     NaN        NaN
# 1677  FormationSet  Successful       NaN   NaN   NaN     NaN        NaN
#
# [639 rows x 15 columns]

# %%
average_locations = successful.groupby('passer').agg({'x':['mean'], 'y':['mean','count']})
average_locations.columns = ['x', 'y', 'count']

# %%
average_locations.head(1000)
# Out:
#                 x          y  count
# passer
# 1.0      6.664516  50.448387     31
# 2.0     64.923404  12.493617     47
# 4.0     32.767308  44.057692     52
# 8.0     52.890526  41.813684     95
# 9.0     74.888235  51.929412     17
# 10.0    66.644444  44.650617     81
# 15.0    38.513846  75.132308     65
# 16.0    69.100000  68.493478     46
# 18.0    50.846032  79.749206     63
# 21.0    52.098611  50.661111     72
# 28.0    46.904688  16.464063     64

# %%
pass_between = successful.groupby(['passer','recipient']).id.count().reset_index()
pass_between.rename({'id':'pass_count'}, axis='columns', inplace=True)

#sql left join 
pass_between = pass_between.merge(average_locations, left_on='passer', right_index=True)
pass_between = pass_between.merge(average_locations, left_on='recipient', right_index=True, suffixes=['', '_end'])

# %%
pass_between
# Out:
#      passer  recipient  pass_count          x          y  count      x_end  \
# 0       1.0        1.0           6   6.664516  50.448387     31   6.664516
# 10      2.0        1.0           2  64.923404  12.493617     47   6.664516
# 20      4.0        1.0           5  32.767308  44.057692     52   6.664516
# 29      8.0        1.0           1  52.890526  41.813684     95   6.664516
# 49     10.0        1.0           1  66.644444  44.650617     81   6.664516
# ..      ...        ...         ...        ...        ...    ...        ...
# 64     15.0       10.0           1  38.513846  75.132308     65  66.644444
# 74     16.0       10.0          11  69.100000  68.493478     46  66.644444
# 85     18.0       10.0           7  50.846032  79.749206     63  66.644444
# 94     21.0       10.0          14  52.098611  50.661111     72  66.644444
# 105    28.0       10.0           5  46.904688  16.464063     64  66.644444
#
#          y_end  count_end
# 0    50.448387         31
# 10   50.448387         31
# 20   50.448387         31
# 29   50.448387         31
# 49   50.448387         31
# ..         ...        ...
# 64   44.650617         81
# 74   44.650617         81
# 85   44.650617         81
# 94   44.650617         81
# 105  44.650617         81
#
# [109 rows x 9 columns]

# %%
pass_between = pass_between[pass_between['pass_count']>3]

# %%
pass_between
# Out:
#      passer  recipient  pass_count          x          y  count      x_end  \
# 0       1.0        1.0           6   6.664516  50.448387     31   6.664516
# 20      4.0        1.0           5  32.767308  44.057692     52   6.664516
# 60     15.0        1.0           7  38.513846  75.132308     65   6.664516
# 11      2.0        2.0           4  64.923404  12.493617     47  64.923404
# 30      8.0        2.0           8  52.890526  41.813684     95  64.923404
# ..      ...        ...         ...        ...        ...    ...        ...
# 54     10.0       10.0          11  66.644444  44.650617     81  66.644444
# 74     16.0       10.0          11  69.100000  68.493478     46  66.644444
# 85     18.0       10.0           7  50.846032  79.749206     63  66.644444
# 94     21.0       10.0          14  52.098611  50.661111     72  66.644444
# 105    28.0       10.0           5  46.904688  16.464063     64  66.644444
#
#          y_end  count_end
# 0    50.448387         31
# 20   50.448387         31
# 60   50.448387         31
# 11   12.493617         47
# 30   12.493617         47
# ..         ...        ...
# 54   44.650617         81
# 74   44.650617         81
# 85   44.650617         81
# 94   44.650617         81
# 105  44.650617         81
#
# [65 rows x 9 columns]

# %%
# Setup the pitch
pitch = Pitch(pitch_type='statsbomb', pitch_color='#22312b', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(16, 11), constrained_layout=False, tight_layout=True)
fig.set_facecolor('#22312b')

arrows = pitch.arrows(1.2*pass_between.x, .8*pass_between.y, 1.2*pass_between.x_end, .8*pass_between.y_end, ax=ax, width = 3, headwidth = 3, color = 'white', zorder= 1, alpha = .5)

nodes = pitch.scatter(1.2*average_locations.x, 0.8*average_locations.y, s = 300, color ='#d3d3d3', edgecolors='black', linewidth = 2.5, alpha = 1, zorder = 1, ax=ax)

# %%
print(pass_between.columns)
# Out:
# Index(['passer', 'recipient', 'pass_count', 'x', 'y', 'count', 'x_end',
#        'y_end', 'count_end'],
#       dtype='object')

# %%
#from the average_locations passer column, grab the numbers and plot them. Ask Chatgpt, show formation as well
